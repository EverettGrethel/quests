# %%
import math
import numpy as np

from bayes_opt import BayesianOptimization
from bayes_opt.acquisition import ExpectedImprovement

from ase.build import bulk, make_supercell
from ase import Atoms
from ase.io import read, write

from pyace import create_multispecies_basis_config
from pyace.activelearning import compute_B_projections
from quests.entropy import perfect_entropy

# ---------- Categorical choices (extend if you like) ----------
RADBASE_CHOICES = ["SBessel"]  # e.g., ["SBessel", "SomeOtherRadbase"]
NPOT_CHOICES    = ["FinnisSinclairShiftedScaled"]  # e.g., add "Quadratic", "Morse", etc.

def idx_to_choice(idx_float, choices):
    # map a continuous [0, len-1] to a discrete choice
    i = int(round(max(0, min(len(choices)-1, idx_float))))
    return choices[i]

def make_basis_config(params):
    def iround(x, lo, hi):
        return int(max(lo, min(hi, round(x))))

    # --- categoricals via index (keep your lists) ---
    radbase = idx_to_choice(params["radbase_idx"], RADBASE_CHOICES)
    npot    = idx_to_choice(params["npot_idx"], NPOT_CHOICES)

    # --- integers with order constraints ---
    ndensity = iround(params.get("ndensity", 1), 1, 3)

    n1 = iround(params["nrad1"], 4, 12)
    n2 = iround(params["nrad2"], 4, 12)
    n3 = iround(params["nrad3"], 2, 10)
    n1, n2, n3 = sorted([n1, n2, n3], reverse=True)

    l1 = iround(params["lmax1"], 0, 2)
    l2 = iround(params["lmax2"], 2, 10); l2 = max(l2, l1)
    l3 = iround(params["lmax3"], 2, 8);  l3 = min(l3, l2)

    # --- fs_parameters: 2 numbers per density channel ---
    base_p0 = float(params["fs_p0"])
    base_p1 = float(params["fs_p1"])
    fs_params = []
    for _ in range(ndensity):
        fs_params.extend([base_p0, base_p1])

    # sanity check (fail fast instead of deep in pyACE)
    assert len(fs_params) == 2 * ndensity, (
        f"fs_parameters length {len(fs_params)} != 2*ndensity {2*ndensity}"
    )

    basis_config = {
        "deltaSplineBins": float(params["deltaSplineBins"]),
        "elements": ['Au'],

        "embeddings": {
            "ALL": {
                "npot": npot,
                "fs_parameters": fs_params,   # <-- never empty now
                "ndensity": ndensity,
            },
        },

        "bonds": {
            "ALL": {
                "radbase": radbase,
                "radparameters": [ float(params["radparam0"]) ],
                "rcut": float(params["rcut"]),
                "dcut": float(params["dcut"]),
            }
        },

        "functions": {
            "ALL": {
                "nradmax_by_orders": [ n1, n2, n3 ],
                "lmax_by_orders"   : [ l1, l2, l3 ],
            }
        }
    }

    return basis_config



def user_score(train_basis_config):
    test_basis_config = {
        "deltaSplineBins": 0.001,
        "elements": ['C'],

        "embeddings": {
            "ALL": {
            "npot": 'FinnisSinclairShiftedScaled', # ?
            "fs_parameters": [ 1, 1],
            "ndensity": 1, # ?
            },
        },

        "bonds": {
            "ALL": {
            "radbase": "SBessel",
            "radparameters": [ 5.25 ],
            "rcut": 6, # ?
            "dcut": 0.01, # ?
            }
        },

        "functions": {
            # "number_of_functions_per_element": 1000,
            "ALL": {
                "nradmax_by_orders": [ 8,8,6],
                "lmax_by_orders"   : [ 0,6,4] }
        }
    }
    train_basis = create_multispecies_basis_config(train_basis_config)
    test_basis = create_multispecies_basis_config(test_basis_config)

    a1 = 3.58
    supercell = 1
    fcc1 = bulk('Au', 'fcc', a=a1, cubic=True)

    fcc2 = fcc1.copy()
    fcc2.set_cell(0.99 * fcc2.cell, scale_atoms=True)

    # fcc1 = make_supercell(fcc1, np.eye(3) * supercell)
    # fcc2 = make_supercell(fcc2, np.eye(3) * supercell)

    x1 = compute_B_projections(train_basis, [fcc1])[0]
    x2 = compute_B_projections(train_basis, [fcc2])[0]

    distance = np.linalg.norm(x1 - x2)

    x_test = compute_B_projections(test_basis, frames_list)[0]
    H = perfect_entropy(x_test, h=distance, batch_size=10000)
    diff = abs(H - 5.6085074467370095)
    return -diff


# ---------- BO target wrapper ----------
def target_fn(**train_params):
    train_config = make_basis_config(train_params)
    return user_score(train_config)

# ---------- Parameter bounds ----------
pbounds = {
    # Cutoffs / smoothing
    "rcut": (4.5, 8.0),
    "dcut": (0.005, 0.20),
    "deltaSplineBins": (5e-5, 5e-3),

    # Radial basis parameter (SBessel)
    "radparam0": (3.0, 8.0),

    # Embedding potential + parameters
    "npot_idx": (0, len(NPOT_CHOICES)-1),  # categorical via index
    "fs_p0": (0.5, 3.0),
    "fs_p1": (0.5, 3.0),
    "ndensity": (1, 3),  # will be rounded to 1..3

    # Resolution by body order
    "nrad1": (4, 12),
    "nrad2": (4, 12),
    "nrad3": (2, 10),

    "lmax1": (0, 2),
    "lmax2": (2, 10),
    "lmax3": (2, 8),

    # Categorical radial base (index)
    "radbase_idx": (0, len(RADBASE_CHOICES)-1),
}

data_name = "Graphite"
path = f"/home/evere/dev/quests/examples/gap20/{data_name}.xyz"
frames_list = read(path, index=":")

acq = ExpectedImprovement(xi=0.01)

optimizer = BayesianOptimization(
    f=target_fn,
    pbounds=pbounds,
    acquisition_function=acq,
    verbose=2,
    random_state=42,
)

optimizer.maximize(init_points=10, n_iter=40)

print("Best score & params:")
print(optimizer.max)
# Out:
# warning: fast C maxvol functions are not compiled, continue with python maxvol functions
# |   iter    |  target   |   rcut    |   dcut    | deltaS... | radparam0 | npot_idx  |   fs_p0   |   fs_p1   | ndensity  |   nrad1   |   nrad2   |   nrad3   |   lmax1   |   lmax2   |   lmax3   | radbas... |
# -------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[1], line 190
#     180 acq = ExpectedImprovement(xi=0.01)
#     182 optimizer = BayesianOptimization(
#     183     f=target_fn,
#     184     pbounds=pbounds,
#    (...)    187     random_state=42,
#     188 )
# --> 190 optimizer.maximize(init_points=10, n_iter=40)
#     192 print("Best score & params:")
#     193 print(optimizer.max)
#
# File ~/env/quests_py311/lib/python3.11/site-packages/bayes_opt/bayesian_optimization.py:322, in BayesianOptimization.maximize(self, init_points, n_iter)
#     320     x_probe = self.suggest()
#     321     iteration += 1
# --> 322 self.probe(x_probe, lazy=False)
#     324 if self._bounds_transformer and iteration > 0:
#     325     # The bounds transformer should only modify the bounds after
#     326     # the init_points points (only for the true iterations)
#     327     self.set_bounds(self._bounds_transformer.transform(self._space))
#
# File ~/env/quests_py311/lib/python3.11/site-packages/bayes_opt/bayesian_optimization.py:239, in BayesianOptimization.probe(self, params, lazy)
#     237     self._queue.append(params)
#     238 else:
# --> 239     self._space.probe(params)
#     240     self.logger.log_optimization_step(
#     241         self._space.keys, self._space.res()[-1], self._space.params_config, self.max
#     242     )
#
# File ~/env/quests_py311/lib/python3.11/site-packages/bayes_opt/target_space.py:555, in TargetSpace.probe(self, params)
#     553     error_msg = "No target function has been provided."
#     554     raise ValueError(error_msg)
# --> 555 target = self.target_func(**dict_params)
#     557 if self._constraint is None:
#     558     self.register(x, target)
#
# Cell In[1], line 145, in target_fn(**train_params)
#     143 def target_fn(**train_params):
#     144     train_config = make_basis_config(train_params)
# --> 145     return user_score(train_config)
#
# Cell In[1], line 136, in user_score(train_basis_config)
#     132 x2 = compute_B_projections(train_basis, [fcc2])[0]
#     134 distance = np.linalg.norm(x1 - x2)
# --> 136 x_test = compute_B_projections(test_basis, frames_list)[0]
#     137 H = perfect_entropy(x_test, h=distance, batch_size=10000)
#     138 diff = abs(H - 5.6085074467370095)
#
# File ~/env/quests_py311/lib/python3.11/site-packages/pyace/activelearning.py:164, in compute_B_projections(bconf, atomic_env_list, structure_ind_list, is_full, compute_forces_dict, return_structure_ind_dict, verbose)
#     162 progress_wrapper = tqdm if verbose else simple_tqdm
#     163 for struct_ind, ae in progress_wrapper(zip(tmp_structure_ind_list, atomic_env_list), total=len(atomic_env_list)):
# --> 164     calc.compute(ae, compute_projections=True)
#     165     if is_full:
#     166         basis_projections = calc.dE_dc
#
# KeyboardInterrupt:
